# %%
import pandas as pd

# %%
risposte=pd.read_csv("File dati_Ortona (1200)_ETICHETTE.csv",sep=';')

# %%
risposte
# Out:
#         ID   Q002           Q005        Q006                         Q007  \
# 0        1  Donna     45-54 anni         sud  da 100001 a 250000 abitanti
# 1        2   Uomo     35-44 anni      centro   da 30001 a 100000 abitanti
# 2        3   Uomo  oltre 64 anni  nord-ovest  da 100001 a 250000 abitanti
# 3        4   Uomo  oltre 64 anni         sud     da 5001 a 10000 abitanti
# 4        5  Donna     35-44 anni    nord-est    da 10001 a 30000 abitanti
# ...    ...    ...            ...         ...                          ...
# 1299  1300   Uomo     18-24 anni  nord-ovest        oltre 250000 abitanti
# 1300  1301   Uomo     25-34 anni         sud         fino a 5000 abitanti
# 1301  1302  Donna     25-34 anni  nord-ovest  da 100001 a 250000 abitanti
# 1302  1303  Donna     18-24 anni         sud     da 5001 a 10000 abitanti
# 1303  1304  Donna     18-24 anni    nord-est   da 30001 a 100000 abitanti
#
#            Q008                                            Q009  \
# ...
