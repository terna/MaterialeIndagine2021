# %%
import pandas as pd

# %%
dati=pd.read_csv("Questionario.csv",sep=',')

# %%
#dati

# %% [markdown]
# #### campi del questionario
#
# Informazioni cronologiche
#
#     In automatico, indicazione del momento della risposta
#
# Domanda 1.  Ritieni che lo Stato dovrebbe intervenire, creando direttamente posti di lavoro?
#
#     Sì
#     No
#     Non saprei
#
# Domanda 2. Saresti favorevole a un piano straordinario di assunzioni nella Pubblica Amministrazione finanziate con un piccolo prelievo fiscale (l’1) sui PATRIMONI FINANZIARI, quindi conti in banca, azioni, obbligazioni, bot, ma NON su case, terreni o altri beni immobili, con una quota esente di 100.000E. (Quindi chi avesse un patrimonio inferiore a 100.000E non pagherebbe nulla, chi avesse un patrimonio di 150.000E pagherebbe l’1 di 50.000E perché i primi 100.000 sarebbero esenti, chi avesse un patrimonio d1 200.000E pagherebbe l’1 di 100.000E e così via).
#
#     Sarei abbastanza favorevole
#     Sarei molto favorevole
#     Sarei piuttosto contrario
#     Sarei molto contrario
#     Non saprei
#
# Domanda 3. In un eventuale sondaggio su un campione rappresentativo a livello nazionale, quale percentuale (circa) di intervistati secondo te risponderebbe sì alla domanda 1?
#
# Domanda 4. E quale percentuale (circa) dichiarerebbe di essere favorevole (abbastanza+molto) rispondendo alla domanda 2?
#
# Domanda 5. Sei un/una
#
#     Economista
#     Altro

# %%
pd.set_option('display.float_format', lambda x: '%.1f' % x)

# %%
pd.crosstab(dati[dati.columns[1]], dati[dati.columns[2]])
# Out:
# Domanda 2. Saresti favorevole a un piano straordinario di assunzioni nella Pubblica Amministrazione finanziate con un piccolo prelievo fiscale (l’1) sui PATRIMONI FINANZIARI, quindi conti in banca, azioni, obbligazioni, bot, ma NON su case, terreni o altri beni immobili, con una quota esente di 100.000E. (Quindi chi avesse un patrimonio inferiore a 100.000E non pagherebbe nulla, chi avesse un patrimonio di 150.000E pagherebbe l’1 di 50.000E perché i primi 100.000 sarebbero esenti, chi avesse un patrimonio d1 200.000E pagherebbe l’1 di 100.000E e così via).  Non saprei  \
# Domanda 1.  Ritieni che lo Stato dovrebbe inter...
# ...

# %%
pd.crosstab(dati[dati.columns[1]], dati[dati.columns[3]])
# Out:
# Domanda 3. In un eventuale sondaggio su un campione rappresentativo a livello nazionale, quale percentuale (circa) di intervistati secondo te risponderebbe sì alla domanda 1?  0   \
# Domanda 1.  Ritieni che lo Stato dovrebbe inter...
# No                                                                                                                                                                               1
# Non saprei                                                                                                                                                                       0
# Sì                                                                                                                                                                               0
#
# Domanda 3. In un eventuale sondaggio su un campione rappresentativo a livello nazionale, quale percentuale (circa) di intervistati secondo te risponderebbe sì alla domanda 1?  10  \
# ...

# %%
pd.crosstab(dati[dati.columns[2]], dati[dati.columns[4]])
# Out:
# Domanda 4. E quale percentuale (circa) dichiarerebbe di essere favorevole (abbastanza+molto) rispondendo alla domanda 2?  0   \
# Domanda 2. Saresti favorevole a un piano straor...
# Non saprei                                                                                                                 0
# Sarei abbastanza favorevole                                                                                                0
# Sarei molto contrario                                                                                                      1
# Sarei molto favorevole                                                                                                     0
# Sarei piuttosto contrario                                                                                                  0
#
# Domanda 4. E quale percentuale (circa) dichiarerebbe di essere favorevole (abbastanza+molto) rispondendo alla domanda 2?  10  \
# ...

# %%
pd.crosstab(dati[dati.columns[2]], dati[dati.columns[5]])
# Out:
# Domanda 5. Sei un/una                               Altro  Economista
# Domanda 2. Saresti favorevole a un piano straor...
# Non saprei                                              2           0
# Sarei abbastanza favorevole                             5           6
# Sarei molto contrario                                   0           7
# Sarei molto favorevole                                  0           5
# Sarei piuttosto contrario                               4           4
